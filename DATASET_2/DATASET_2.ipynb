# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
pd.read_csv('/workspaces/trabajo-coderhouse/DATASET_2/dnrpa-robos-recuperos-autos-201906.csv')
# Out:
#                                        tramite_tipo tramite_fecha  \
# 0     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-18
# 1     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-01
# 2     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-24
# 3     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-16
# 4     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-28
# ...                                             ...           ...
# 3413  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-25
# 3414  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-07
# 3415  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-14
# 3416  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-16
# 3417  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-29
#
#      fecha_inscripcion_inicial  registro_seccional_codigo  \
# 0                   2007-05-04                       1005
# ...

# %%
df= pd.read_csv('/workspaces/trabajo-coderhouse/DATASET_2/dnrpa-robos-recuperos-autos-201906.csv')

# %%
df
# Out:
#                                        tramite_tipo tramite_fecha  \
# 0     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-18
# 1     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-01
# 2     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-24
# 3     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-16
# 4     DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-28
# ...                                             ...           ...
# 3413  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-25
# 3414  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-07
# 3415  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-14
# 3416  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-16
# 3417  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-11-29
#
#      fecha_inscripcion_inicial  registro_seccional_codigo  \
# 0                   2007-05-04                       1005
# ...

# %%
df.shape
# Out:
# (3418, 25)

# %% [markdown]
# lo que podria predecir con este datasets seria: titular_domicilio_provincia  (saber que provincia tuvo mas robos)
# las variables relevantes serian:  titular_domicilio_localidad: ya que esto me indicaria a que provincia pertenece
# registro_seccional_descripcion: me indica la seccional de esa provincia.
# registro_seccional_codigo: esa seccional tiene codigo de registro
