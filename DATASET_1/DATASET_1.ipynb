# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
pd.read_csv('/workspaces/trabajo-coderhouse/DATASET_1/owid_covid_data.csv')
# Out:
#               date iso_code continent     location  total_cases  new_cases  \
# 0       2020-02-24      AFG      Asia  Afghanistan          5.0        5.0
# 1       2020-02-25      AFG      Asia  Afghanistan          5.0        0.0
# 2       2020-02-26      AFG      Asia  Afghanistan          5.0        0.0
# 3       2020-02-27      AFG      Asia  Afghanistan          5.0        0.0
# 4       2020-02-28      AFG      Asia  Afghanistan          5.0        0.0
# ...            ...      ...       ...          ...          ...        ...
# 213327  2022-08-28      ZWE    Africa     Zimbabwe     256699.0       17.0
# 213328  2022-08-29      ZWE    Africa     Zimbabwe     256704.0        5.0
# 213329  2022-08-30      ZWE    Africa     Zimbabwe     256708.0        4.0
# 213330  2022-08-31      ZWE    Africa     Zimbabwe     256726.0       18.0
# 213331  2022-09-01      ZWE    Africa     Zimbabwe     256738.0       12.0
#
# ...

# %%
df=pd.read_csv('/workspaces/trabajo-coderhouse/DATASET_1/owid_covid_data.csv')

# %%
df
# Out:
#               date iso_code continent     location  total_cases  new_cases  \
# 0       2020-02-24      AFG      Asia  Afghanistan          5.0        5.0
# 1       2020-02-25      AFG      Asia  Afghanistan          5.0        0.0
# 2       2020-02-26      AFG      Asia  Afghanistan          5.0        0.0
# 3       2020-02-27      AFG      Asia  Afghanistan          5.0        0.0
# 4       2020-02-28      AFG      Asia  Afghanistan          5.0        0.0
# ...            ...      ...       ...          ...          ...        ...
# 213327  2022-08-28      ZWE    Africa     Zimbabwe     256699.0       17.0
# 213328  2022-08-29      ZWE    Africa     Zimbabwe     256704.0        5.0
# 213329  2022-08-30      ZWE    Africa     Zimbabwe     256708.0        4.0
# 213330  2022-08-31      ZWE    Africa     Zimbabwe     256726.0       18.0
# 213331  2022-09-01      ZWE    Africa     Zimbabwe     256738.0       12.0
#
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
df.sample(50)
# Out:
#               date  iso_code      continent                         location  \
# 151810  2020-10-03       PER  South America                             Peru
# 111960  2021-03-18  OWID_LIC            NaN                       Low income
# 142384  2021-02-02       MKD         Europe                  North Macedonia
# 149904  2020-07-08       PNG        Oceania                 Papua New Guinea
# 16745   2020-08-27       BRB  North America                         Barbados
# 119247  2021-01-01       MLI         Africa                             Mali
# 183602  2022-03-14       SUR  South America                         Suriname
# 165997  2022-05-08       SMR         Europe                       San Marino
# 162324  2021-06-20       LCA  North America                      Saint Lucia
# 98600   2020-07-26       JOR           Asia                           Jordan
# 38963   2021-11-01       CHL  South America                            Chile
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df
# Out:
#               date iso_code continent     location  total_cases  new_cases  \
# 0       2020-02-24      AFG      Asia  Afghanistan          5.0        5.0
# 1       2020-02-25      AFG      Asia  Afghanistan          5.0        0.0
# 2       2020-02-26      AFG      Asia  Afghanistan          5.0        0.0
# 3       2020-02-27      AFG      Asia  Afghanistan          5.0        0.0
# 4       2020-02-28      AFG      Asia  Afghanistan          5.0        0.0
# ...            ...      ...       ...          ...          ...        ...
# 213327  2022-08-28      ZWE    Africa     Zimbabwe     256699.0       17.0
# 213328  2022-08-29      ZWE    Africa     Zimbabwe     256704.0        5.0
# 213329  2022-08-30      ZWE    Africa     Zimbabwe     256708.0        4.0
# 213330  2022-08-31      ZWE    Africa     Zimbabwe     256726.0       18.0
# 213331  2022-09-01      ZWE    Africa     Zimbabwe     256738.0       12.0
#
# ...

# %%
df.shape
# Out:
# (213332, 70)

# %% [markdown]
# lo que quiero predecir es la mayor cantidad de casos de muerte. los variables relevantes serian:
# location: ya que pienso que depende la zona tuvieron mayor o menor cuidado ante la propagacion del virus
# life_expectancy: el promedio de edad de expectativa de vida
# hospital_beds_per_thousand: camas de hospital cada mil habitantes .
